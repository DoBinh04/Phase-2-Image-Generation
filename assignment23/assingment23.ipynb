# %%
# !python smoke_test.py
# Out:
# [conditional=False, schedule=linear] loss=1.1783  OK
# [conditional=False] DDPM sample shape (4, 1, 32, 32)  OK
# [conditional=False] DDIM sample shape (4, 1, 32, 32)  OK
# [conditional=True, schedule=linear] loss=1.0480  OK
# [conditional=True] DDPM sample shape (4, 1, 32, 32)  OK
# [conditional=True] DDIM sample shape (4, 1, 32, 32)  OK
# [conditional=False, schedule=cosine] loss=1.1315  OK
# [conditional=False] DDPM sample shape (4, 1, 32, 32)  OK
# [conditional=False] DDIM sample shape (4, 1, 32, 32)  OK
# [conditional=True, schedule=cosine] loss=1.1588  OK
# [conditional=True] DDPM sample shape (4, 1, 32, 32)  OK
# [conditional=True] DDIM sample shape (4, 1, 32, 32)  OK
#
# All smoke tests passed.

# %%
# !python train.py \
  --epochs 20 \
  --batch_size 128 \
  --schedule cosine \
  --conditional \
  --p_uncond 0.1 \
  --sample_every 5
# Out:
# Using device: cuda
# 100% 9.91M/9.91M [00:01<00:00, 4.98MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 129kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.20MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 15.1MB/s]
# Model params: 6.12M
# Conditional: True | schedule: cosine | T: 1000
# epoch 0 step 100 loss 0.0837
# epoch 0 step 200 loss 0.0536
# epoch 0 step 300 loss 0.0497
# epoch 0 step 400 loss 0.0522
# == epoch 0 done | avg loss 0.0883 ==
# epoch 1 step 500 loss 0.0435
# epoch 1 step 600 loss 0.0372
# epoch 1 step 700 loss 0.0432
# epoch 1 step 800 loss 0.0400
# epoch 1 step 900 loss 0.0368
# == epoch 1 done | avg loss 0.0396 ==
# epoch 2 step 1000 loss 0.0368
# epoch 2 step 1100 loss 0.0398
# epoch 2 step 1200 loss 0.0357
# epoch 2 step 1300 loss 0.0302
# epoch 2 step 1400 loss 0.0358
# == epoch 2 done | avg loss 0.0352 ==
# epoch 3 step 1500 loss 0.0365
# epoch 3 step 1600 loss 0.0355
# epoch 3 step 1700 loss 0.0365
# epoch 3 step 1800 loss 0.0283
# == epoch 3 done | avg loss 0.0333 ==
# ...

# %%
# !python sample.py \
  --ckpt checkpoints/ddpm_last.pt \
  --conditional \
  --schedule cosine \
  --n_per_class 8 \
  --guidance_scale 3.0 \
  --sampler ddim \
  --ddim_steps 50 \
  --out samples/class_conditional_grid.png
# Out:
# Saved 80 samples to samples/class_conditional_grid.png
# Each row = 1 digit class (0-9 top to bottom), 8 samples per row, guidance_scale=3.0

# %%
from IPython.display import Image, display
display(Image("samples/class_conditional_grid.png"))

# %%
from IPython.display import display, Image
display(Image("samples/epoch_004.png"))
display(Image("samples/epoch_009.png"))
display(Image("samples/epoch_014.png"))
display(Image("samples/epoch_019.png"))

# %%
# !python verify_ddim.py \
  --ckpt /content/assignment22/checkpoints/ddpm_last.pt \
  --conditional \
  --schedule cosine \
  --timesteps 1000 \
  --base_ch 64
# Out:
# Using device: cuda
#
# [Test 1] DDIM step reproduces the exact forward-process trajectory (eta=0, no model)
#   max abs error over 20 random (t, s, x0, eps) trials: 9.42e-06  (tol=2e-04)
#   PASS
#
# [Test 2] DDIM eta=1 variance matches the DDPM posterior variance (adjacent steps, no model)
#   max relative error across sampled t in [1, 1000): 1.66e-04  (tol=2e-04)
#   PASS
#
# [Test 3] eta=0 DDIM sampling is deterministic given the same x_T (needs checkpoint)
#   max abs difference between two eta=0 runs from the same x_T: 0.00e+00  (tol=2e-04)
#   PASS
#
# [Test 4] DDIM output converges toward the many-step reference as step count grows (needs checkpoint)
#   steps=5     mean abs error vs 200-step reference = 0.5126
#   steps=10    mean abs error vs 200-step reference = 0.4645
#   steps=20    mean abs error vs 200-step reference = 0.3774
#   steps=50    mean abs error vs 200-step reference = 0.2577
#   steps=100   mean abs error vs 200-step reference = 0.1570
# ...

# %%
# !python sample_ddim.py \
  --ckpt /content/assignment22/checkpoints/ddpm_last.pt \
  --conditional \
  --schedule cosine \
  --timesteps 1000 \
  --base_ch 64 \
  --n_per_class 8 \
  --guidance_scale 3.0 \
  --ddim_steps 50 \
  --eta 0.0 \
  --out_dir samples
# Out:
# Using device: cuda
# Saved DDIM samples (50 steps, eta=0.0) -> samples/ddim_50steps_eta0.0.png

# %%
from IPython.display import Image, display
display(Image("samples/ddim_50steps_eta0.0.png"))

# %%
# !python sample_ddim.py \
  --ckpt /content/assignment22/checkpoints/ddpm_last.pt \
  --conditional --schedule cosine \
  --n_per_class 8 --guidance_scale 3.0 \
  --ddim_steps 50 --eta 0.0 \
  --compare_ddpm --out_dir samples
# Out:
# Using device: cuda
# Saved DDIM samples (50 steps, eta=0.0) -> samples/ddim_50steps_eta0.0.png
# Saved DDPM baseline samples (1000 steps) -> samples/ddpm_1000steps.png
# Saved side-by-side (row1=DDPM/1000, row2=DDIM/50) -> samples/ddpm_vs_ddim.png

# %%
from IPython.display import Image, display
display(Image("samples/ddpm_vs_ddim.png"))
