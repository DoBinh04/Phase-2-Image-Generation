# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# CUDA: True
# GPU: Tesla T4

# %%
# !python verify_vae.py
# Out:
# --- MNIST-config: in_channels=1, img_size=32 ---
# [PASS] MNIST-config: recon shape == input shape
# [PASS] MNIST-config: mu shape == (4, latent_dim)
# [PASS] MNIST-config: logvar shape == (4, latent_dim)
# [PASS] MNIST-config: recon output in [0,1]
# [PASS] MNIST-config: loss is finite
# [PASS] MNIST-config: every parameter received a gradient
# [PASS] MNIST-config: gradients are finite and non-zero overall
# [PASS] MNIST-config: sample() shape correct
#
# --- CelebA-config: in_channels=3, img_size=64 ---
# [PASS] CelebA-config: recon shape == input shape
# [PASS] CelebA-config: mu shape == (4, latent_dim)
# [PASS] CelebA-config: logvar shape == (4, latent_dim)
# [PASS] CelebA-config: recon output in [0,1]
# [PASS] CelebA-config: loss is finite
# [PASS] CelebA-config: every parameter received a gradient
# [PASS] CelebA-config: gradients are finite and non-zero overall
# [PASS] CelebA-config: sample() shape correct
#
# --- KL sanity: q(z|x) == prior N(0,I) => KL ~= 0 ---
# [PASS] KL(N(0,I) || N(0,I)) ~= 0
#
# --- Reparameterization: sampling is stochastic but unbiased ---
# [PASS] two samples from the same mu/logvar differ
# [PASS] empirical mean over 2000 samples ~= 0 (got -0.004)
#
# --- Overfit test (MNIST-like): can the model memorize one small batch? ---
#     loss[0]=115.8724  ->  loss[299]=1.7013
# [PASS] overfit loss decreases substantially (>90% drop)
#     final pixel-wise MSE on memorized batch: 0.00107
# [PASS] final reconstruction MSE is small (<0.01)
#
# ALL CHECKS PASSED ✅ — model kiến trúc, gradient, và khả năng học đều ổn.

# %%
# !python vae.py \
    --dataset mnist \
    --epochs 15 \
    --batch-size 128 \
    --latent-dim 128 \
    --base-ch 32 \
    --beta 1.0 \
    --recon mse
# Out:
# device: cuda
# 100% 9.91M/9.91M [00:00<00:00, 17.2MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 456kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.27MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 15.2MB/s]
# VAE(
#   (encoder): Encoder(
#     (conv): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=0.2, inplace=True)
#       (6): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): LeakyReLU(negative_slope=0.2, inplace=True)
#       (9): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (fc_mu): Linear(in_features=1024, out_features=128, bias=True)
#     (fc_logvar): Linear(in_features=1024, out_features=128, bias=True)
#   )
#   (decoder): Decoder(
#     (fc): Linear(in_features=128, out_features=1024, bias=True)
#     (deconv): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): ConvTranspose2d(32, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (10): Sigmoid()
#     )
#   )
# )
# total parameters: 1,773,889
# epoch 1 [   0/468] loss=307.87  recon=290.42  kl=17.44
# epoch 1 [ 100/468] loss=48.19  recon=41.73  kl=6.46
# epoch 1 [ 200/468] loss=40.70  recon=31.81  kl=8.89
# epoch 1 [ 300/468] loss=38.44  recon=27.02  kl=11.41
# epoch 1 [ 400/468] loss=36.11  recon=23.93  kl=12.19
# == epoch 1 == train loss=48.54 (recon=39.60, kl=8.95)  |  test loss=33.72 (recon=21.91, kl=11.80)
# epoch 2 [   0/468] loss=34.70  recon=23.26  kl=11.44
# epoch 2 [ 100/468] loss=33.63  recon=22.13  kl=11.50
# epoch 2 [ 200/468] loss=31.93  recon=20.42  kl=11.51
# epoch 2 [ 300/468] loss=30.45  recon=19.53  kl=10.92
# epoch 2 [ 400/468] loss=31.01  recon=19.15  kl=11.87
# == epoch 2 == train loss=31.89 (recon=20.20, kl=11.68)  |  test loss=29.90 (recon=18.19, kl=11.71)
# epoch 3 [   0/468] loss=30.21  recon=18.88  kl=11.33
# epoch 3 [ 100/468] loss=30.41  recon=18.30  kl=12.11
# epoch 3 [ 200/468] loss=29.52  recon=17.68  kl=11.84
# epoch 3 [ 300/468] loss=29.86  recon=17.60  kl=12.26
# epoch 3 [ 400/468] loss=30.84  recon=18.40  kl=12.43
# == epoch 3 == train loss=29.80 (recon=17.79, kl=12.02)  |  test loss=29.22 (recon=17.48, kl=11.75)
# epoch 4 [   0/468] loss=28.44  recon=17.17  kl=11.27
# epoch 4 [ 100/468] loss=29.53  recon=17.11  kl=12.42
# epoch 4 [ 200/468] loss=30.23  recon=18.03  kl=12.20
# epoch 4 [ 300/468] loss=28.90  recon=16.70  kl=12.20
# epoch 4 [ 400/468] loss=28.67  recon=16.62  kl=12.04
# == epoch 4 == train loss=28.94 (recon=16.79, kl=12.15)  |  test loss=28.21 (recon=15.78, kl=12.44)
# epoch 5 [   0/468] loss=29.37  recon=16.90  kl=12.47
# epoch 5 [ 100/468] loss=28.24  recon=15.84  kl=12.40
# epoch 5 [ 200/468] loss=28.04  recon=15.26  kl=12.78
# epoch 5 [ 300/468] loss=29.43  recon=16.64  kl=12.79
# epoch 5 [ 400/468] loss=27.62  recon=15.24  kl=12.39
# == epoch 5 == train loss=28.25 (recon=16.00, kl=12.26)  |  test loss=27.60 (recon=15.20, kl=12.40)
# epoch 6 [   0/468] loss=28.70  recon=16.02  kl=12.68
# epoch 6 [ 100/468] loss=27.61  recon=15.21  kl=12.41
# epoch 6 [ 200/468] loss=28.76  recon=16.87  kl=11.89
# epoch 6 [ 300/468] loss=27.21  recon=14.67  kl=12.54
# epoch 6 [ 400/468] loss=29.44  recon=16.35  kl=13.09
# == epoch 6 == train loss=27.90 (recon=15.57, kl=12.33)  |  test loss=27.85 (recon=15.67, kl=12.19)
# epoch 7 [   0/468] loss=27.76  recon=15.29  kl=12.46
# epoch 7 [ 100/468] loss=27.30  recon=14.47  kl=12.83
# epoch 7 [ 200/468] loss=27.25  recon=14.67  kl=12.58
# epoch 7 [ 300/468] loss=26.46  recon=14.61  kl=11.86
# epoch 7 [ 400/468] loss=27.03  recon=14.80  kl=12.23
# == epoch 7 == train loss=27.56 (recon=15.17, kl=12.39)  |  test loss=27.37 (recon=15.05, kl=12.32)
# epoch 8 [   0/468] loss=27.07  recon=14.70  kl=12.37
# epoch 8 [ 100/468] loss=27.28  recon=14.66  kl=12.63
# epoch 8 [ 200/468] loss=27.05  recon=14.65  kl=12.41
# epoch 8 [ 300/468] loss=27.30  recon=14.78  kl=12.52
# epoch 8 [ 400/468] loss=27.46  recon=14.44  kl=13.01
# == epoch 8 == train loss=27.31 (recon=14.90, kl=12.41)  |  test loss=26.82 (recon=14.57, kl=12.26)
# epoch 9 [   0/468] loss=27.07  recon=14.56  kl=12.51
# epoch 9 [ 100/468] loss=26.49  recon=14.51  kl=11.97
# epoch 9 [ 200/468] loss=26.93  recon=14.93  kl=12.00
# epoch 9 [ 300/468] loss=26.78  recon=14.94  kl=11.84
# epoch 9 [ 400/468] loss=27.87  recon=14.93  kl=12.93
# == epoch 9 == train loss=27.12 (recon=14.69, kl=12.43)  |  test loss=27.07 (recon=14.54, kl=12.53)
# epoch 10 [   0/468] loss=26.01  recon=14.14  kl=11.88
# epoch 10 [ 100/468] loss=27.11  recon=14.48  kl=12.64
# epoch 10 [ 200/468] loss=25.96  recon=14.12  kl=11.85
# epoch 10 [ 300/468] loss=27.39  recon=14.68  kl=12.71
# epoch 10 [ 400/468] loss=25.86  recon=13.35  kl=12.52
# == epoch 10 == train loss=26.89 (recon=14.42, kl=12.47)  |  test loss=26.61 (recon=14.08, kl=12.52)
# epoch 11 [   0/468] loss=26.92  recon=13.94  kl=12.97
# epoch 11 [ 100/468] loss=27.94  recon=14.60  kl=13.34
# epoch 11 [ 200/468] loss=27.11  recon=14.66  kl=12.44
# epoch 11 [ 300/468] loss=26.54  recon=13.86  kl=12.68
# epoch 11 [ 400/468] loss=26.48  recon=14.05  kl=12.42
# == epoch 11 == train loss=26.76 (recon=14.29, kl=12.46)  |  test loss=26.55 (recon=14.17, kl=12.38)
# epoch 12 [   0/468] loss=26.32  recon=14.49  kl=11.83
# epoch 12 [ 100/468] loss=26.94  recon=14.13  kl=12.81
# epoch 12 [ 200/468] loss=25.82  recon=13.16  kl=12.66
# epoch 12 [ 300/468] loss=28.06  recon=15.03  kl=13.03
# epoch 12 [ 400/468] loss=26.76  recon=14.23  kl=12.53
# == epoch 12 == train loss=26.65 (recon=14.15, kl=12.50)  |  test loss=26.39 (recon=13.82, kl=12.57)
# epoch 13 [   0/468] loss=27.54  recon=14.97  kl=12.57
# epoch 13 [ 100/468] loss=26.68  recon=14.10  kl=12.58
# epoch 13 [ 200/468] loss=26.99  recon=14.08  kl=12.91
# epoch 13 [ 300/468] loss=25.81  recon=13.14  kl=12.67
# epoch 13 [ 400/468] loss=26.59  recon=14.26  kl=12.33
# == epoch 13 == train loss=26.47 (recon=13.99, kl=12.48)  |  test loss=26.24 (recon=13.61, kl=12.63)
# epoch 14 [   0/468] loss=25.56  recon=13.24  kl=12.32
# epoch 14 [ 100/468] loss=26.04  recon=13.71  kl=12.33
# epoch 14 [ 200/468] loss=26.40  recon=13.86  kl=12.53
# epoch 14 [ 300/468] loss=25.53  recon=13.85  kl=11.67
# epoch 14 [ 400/468] loss=25.40  recon=12.87  kl=12.52
# == epoch 14 == train loss=26.38 (recon=13.87, kl=12.51)  |  test loss=26.22 (recon=13.74, kl=12.48)
# epoch 15 [   0/468] loss=26.86  recon=14.35  kl=12.51
# epoch 15 [ 100/468] loss=26.58  recon=14.19  kl=12.39
# epoch 15 [ 200/468] loss=25.68  recon=13.05  kl=12.63
# epoch 15 [ 300/468] loss=26.67  recon=14.18  kl=12.48
# epoch 15 [ 400/468] loss=27.03  recon=14.40  kl=12.63
# == epoch 15 == train loss=26.29 (recon=13.76, kl=12.52)  |  test loss=26.14 (recon=13.71, kl=12.43)
# saved checkpoint to ./vae_out/vae_final.pt
